# %% [markdown]
# # For code demonstration purposes only. This notebook is intended to teach you techniques.  This is not a script for your project.  Use your own judgment and do what makes sense for your project

# %% [markdown]
# Used Car Prices Data Source
#
# https://www.kaggle.com/datasets/ankits29/used-car-price-data

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
help (pd)
# Out:
# Help on package pandas:
#
# NAME
#     pandas
#
# DESCRIPTION
#     pandas - a powerful data analysis and manipulation library for Python
# ...
#
#     **pandas** is a Python package providing fast, flexible, and expressive data
#     structures designed to make working with "relational" or "labeled" data both
#     easy and intuitive. It aims to be the fundamental high-level building block for
#     doing practical, **real world** data analysis in Python. Additionally, it has
#     the broader goal of becoming **the most powerful and flexible open source data
#     analysis / manipulation tool available in any language**. It is already well on
#     its way toward this goal.
#
#     Main Features
#     -------------
#     Here are just a few of the things that pandas does well:
#
#       - Easy handling of missing data in floating point as well as non-floating
#         point data.
#       - Size mutability: columns can be inserted and deleted from DataFrame and
# ...

# %%
help(sns)
# Out:
# Help on package seaborn:
#
# NAME
#     seaborn - # Import seaborn objects
#
# PACKAGE CONTENTS
#     _core
#     _decorators
#     _docstrings
#     _statistics
#     _testing
#     algorithms
#     apionly
#     axisgrid
#     categorical
#     cm
#     colors (package)
#     conftest
#     distributions
#     external (package)
#     linearmodels
#     matrix
#     miscplot
#     palettes
#     rcmod
#     regression
#     relational
#     tests (package)
#     timeseries
#     utils
#     widgets
#
# DATA
#     crayons = {'Almond': '#EFDECD', 'Antique Brass': '#CD9575', 'Apricot':...
#     xkcd_rgb = {'acid green': '#8ffe09', 'adobe': '#bd6c48', 'algae': '#54...
#
# VERSION
#     0.11.2
#
# FILE
#     /usr/local/lib/python3.8/dist-packages/seaborn/__init__.py

# %%
from google.colab import drive
drive.mount('/content/drive')

CarData = pd.read_csv("drive/MyDrive/COMPTECH/Data/W1-D3/UsedCarPrices/car_data.csv") 
CarData
# Out:
# Mounted at /content/drive
#                         Model  Selling Price  Kilometers Driven  Year  \
# 0          MarutiWagonR1.0LXI         312165              82238  2014
# 1             ToyotaEtiosLiva         313799              30558  2013
# 2               MarutiAlto800         295999              22164  2018
# 3                 MarutiSwift         435199              30535  2013
# 4             MarutiWagonR1.0         289099              15738  2013
# ...                       ...            ...                ...   ...
# 2232          MarutiWagonR1.0         385999              45263  2015
# 2233              MarutiSwift         324099             100335  2012
# 2234              HyundaiEonD         212299              28016  2011
# 2235  FordEcosport1.5AMBIENTE         378899              87947  2013
# 2236            MarutiAltoK10         304299              33639  2015
#
#              Owner     Fuel Type Transmission   Insurance  Car Condition
# ...

# %%
CarData.head()
# Out:
#                 Model  Selling Price  Kilometers Driven  Year        Owner  \
# 0  MarutiWagonR1.0LXI         312165              82238  2014  First Owner
# 1     ToyotaEtiosLiva         313799              30558  2013  First Owner
# 2       MarutiAlto800         295999              22164  2018  First Owner
# 3         MarutiSwift         435199              30535  2013  First Owner
# 4     MarutiWagonR1.0         289099              15738  2013  First Owner
#
#       Fuel Type Transmission   Insurance  Car Condition
# 0  Petrol + CNG       MANUAL     Expired            4.2
# 1        Petrol       MANUAL  12-09-2021            4.4
# 2        Petrol       MANUAL  01-12-2020            4.8
# 3        Diesel       MANUAL        Comp            4.3
# 4        Petrol       MANUAL  11-08-2021            4.3

# %%
CarData.tail()
# Out:
#                         Model  Selling Price  Kilometers Driven  Year  \
# 2232          MarutiWagonR1.0         385999              45263  2015
# 2233              MarutiSwift         324099             100335  2012
# 2234              HyundaiEonD         212299              28016  2011
# 2235  FordEcosport1.5AMBIENTE         378899              87947  2013
# 2236            MarutiAltoK10         304299              33639  2015
#
#              Owner Fuel Type Transmission   Insurance  Car Condition
# 2232  Second Owner    Petrol       MANUAL  10-06-2021            4.4
# 2233  Second Owner    Petrol       MANUAL  02-08-2021            4.3
# 2234   First Owner    Petrol       MANUAL     Expired            3.2
# 2235   First Owner    Diesel       MANUAL  03-09-2021            4.2
# 2236   First Owner    Petrol       MANUAL  17-10-2021            4.1

# %%
CarData.sample(5)
# Out:
#                               Model  Selling Price  Kilometers Driven  Year  \
# 114                    DatsunRediGo         184383              31153  2016
# 1267               Hyundaii20MAGNAO         318736              33023  2013
# 207                 HyundaiEonMAGNA         211499              28323  2014
# 1699  HyundaiGrandi10SPORTZ(O)1.2AT         547099               6267  2017
# 1525                    MarutiSwift         504255              38597  2015
#
#              Owner Fuel Type Transmission   Insurance  Car Condition
# 114   Second Owner    Petrol       MANUAL  25-08-2021            4.4
# 1267   First Owner    Petrol       MANUAL  20-09-2021            4.4
# 207    First Owner    Petrol       MANUAL  05-11-2021            4.5
# 1699   First Owner    Petrol         MH01    Zero_Dep            4.0
# 1525   First Owner    Petrol       MANUAL  10-03-2021            4.6

# %%
CarData.shape
# Out:
# (2237, 9)

# %%
CarData.describe()
# Out:
#        Selling Price  Kilometers Driven         Year  Car Condition
# count   2.237000e+03        2237.000000  2237.000000    2237.000000
# mean    4.184431e+05       61928.605275  2013.763523       4.370854
# std     2.280516e+05       42260.955917     2.874686       0.288990
# min     7.529900e+04         913.000000  2006.000000       3.000000
# 25%     2.720990e+05       32137.000000  2012.000000       4.200000
# 50%     3.557990e+05       55430.000000  2014.000000       4.300000
# 75%     5.032990e+05       83427.000000  2016.000000       4.600000
# max     1.952397e+06      855881.000000  2020.000000       5.000000

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
CarData.describe()
# Out:
#        Selling Price  Kilometers Driven     Year  Car Condition
# count       2,237.00           2,237.00 2,237.00       2,237.00
# mean      418,443.07          61,928.61 2,013.76           4.37
# std       228,051.60          42,260.96     2.87           0.29
# min        75,299.00             913.00 2,006.00           3.00
# 25%       272,099.00          32,137.00 2,012.00           4.20
# 50%       355,799.00          55,430.00 2,014.00           4.30
# 75%       503,299.00          83,427.00 2,016.00           4.60
# max     1,952,397.00         855,881.00 2,020.00           5.00

# %%
CarData.describe(include='O')
# Out:
#               Model        Owner Fuel Type Transmission Insurance
# count          2237         2237      2237         2237      2223
# unique          434            3         4           58       473
# top     MarutiSwift  First Owner    Petrol       MANUAL   Expired
# freq            118         1707      1384         1909       248

# %%
CarData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2237 entries, 0 to 2236
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Model              2237 non-null   object
#  1   Selling Price      2237 non-null   int64
#  2   Kilometers Driven  2237 non-null   int64
#  3   Year               2237 non-null   int64
#  4   Owner              2237 non-null   object
#  5   Fuel Type          2237 non-null   object
#  6   Transmission       2237 non-null   object
#  7   Insurance          2223 non-null   object
#  8   Car Condition      2237 non-null   float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 157.4+ KB

# %%
CarData.describe(include='all')
# Out:
#               Model  Selling Price  Kilometers Driven     Year        Owner  \
# count          2237       2,237.00           2,237.00 2,237.00         2237
# unique          434            NaN                NaN      NaN            3
# top     MarutiSwift            NaN                NaN      NaN  First Owner
# freq            118            NaN                NaN      NaN         1707
# mean            NaN     418,443.07          61,928.61 2,013.76          NaN
# std             NaN     228,051.60          42,260.96     2.87          NaN
# min             NaN      75,299.00             913.00 2,006.00          NaN
# 25%             NaN     272,099.00          32,137.00 2,012.00          NaN
# 50%             NaN     355,799.00          55,430.00 2,014.00          NaN
# 75%             NaN     503,299.00          83,427.00 2,016.00          NaN
# max             NaN   1,952,397.00         855,881.00 2,020.00          NaN
#
#        Fuel Type Transmission Insurance  Car Condition
# ...

# %%
CarData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2237 entries, 0 to 2236
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Model              2237 non-null   object
#  1   Selling Price      2237 non-null   int64
#  2   Kilometers Driven  2237 non-null   int64
#  3   Year               2237 non-null   int64
#  4   Owner              2237 non-null   object
#  5   Fuel Type          2237 non-null   object
#  6   Transmission       2237 non-null   object
#  7   Insurance          2223 non-null   object
#  8   Car Condition      2237 non-null   float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 157.4+ KB

# %%
# Check for duplciates
CarData.duplicated().any()
# Out:
# False

# %%
CarData.isnull()
# Out:
#       Model  Selling Price  Kilometers Driven   Year  Owner  Fuel Type  \
# 0     False          False              False  False  False      False
# 1     False          False              False  False  False      False
# 2     False          False              False  False  False      False
# 3     False          False              False  False  False      False
# 4     False          False              False  False  False      False
# ...     ...            ...                ...    ...    ...        ...
# 2232  False          False              False  False  False      False
# 2233  False          False              False  False  False      False
# 2234  False          False              False  False  False      False
# 2235  False          False              False  False  False      False
# 2236  False          False              False  False  False      False
#
#       Transmission  Insurance  Car Condition
# 0            False      False          False
# ...

# %%
CarData.duplicated().sum()
# Out:
# 0

# %%
CarData.drop_duplicates(inplace=True)

# %%
CarData.columns
# Out:
# Index(['Model', 'Selling Price', 'Kilometers Driven', 'Year', 'Owner',
#        'Fuel Type', 'Transmission', 'Insurance', 'Car Condition'],
#       dtype='object')

# %%
CarData.isnull().sum()
# Out:
# Model                 0
# Selling Price         0
# Kilometers Driven     0
# Year                  0
# Owner                 0
# Fuel Type             0
# Transmission          0
# Insurance            14
# Car Condition         0
# dtype: int64

# %%
def FindMissingColsPercentage(df):

    total = 0
    for col in df.columns:
        missing_vals = df[col].isnull().sum()
        # mean = sum / total
        pct = df[col].isnull().mean() * 100 
        if missing_vals != 0:
          print('{} => {} [{}%]'.format(col, df[col].isnull().sum(), round(pct, 2)))
        total += missing_vals
    
    if total == 0:
        print("no missing values")

# %%
FindMissingColsPercentage(CarData)
# Out:
# Insurance => 14 [0.63%]

# %%
CarData.shape
# Out:
# (2237, 9)

# %%
CarData = CarData.dropna()

# %%
CarData.isnull().sum()
# Out:
# Model                0
# Selling Price        0
# Kilometers Driven    0
# Year                 0
# Owner                0
# Fuel Type            0
# Transmission         0
# Insurance            0
# Car Condition        0
# dtype: int64

# %%
CarData.shape
# Out:
# (2223, 9)

# %%
CarData.columns
# Out:
# Index(['Model', 'Selling Price', 'Kilometers Driven', 'Year', 'Owner',
#        'Fuel Type', 'Transmission', 'Insurance', 'Car Condition'],
#       dtype='object')

# %%
CarData.columns = CarData.columns.str.replace(' ', "_")

# %%
CarData.columns
# Out:
# Index(['Model', 'Selling_Price', 'Kilometers_Driven', 'Year', 'Owner',
#        'Fuel_Type', 'Transmission', 'Insurance', 'Car_Condition'],
#       dtype='object')

# %%
CarData.Selling_Price
# Out:
# 0       312165
# 1       313799
# 2       295999
# 3       435199
# 4       289099
#          ...
# 2232    385999
# 2233    324099
# 2234    212299
# 2235    378899
# 2236    304299
# Name: Selling_Price, Length: 2223, dtype: int64

# %%
CarData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2223 entries, 0 to 2236
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Model              2223 non-null   object
#  1   Selling_Price      2223 non-null   int64
#  2   Kilometers_Driven  2223 non-null   int64
#  3   Year               2223 non-null   int64
#  4   Owner              2223 non-null   object
#  5   Fuel_Type          2223 non-null   object
#  6   Transmission       2223 non-null   object
#  7   Insurance          2223 non-null   object
#  8   Car_Condition      2223 non-null   float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 173.7+ KB

# %%
CarData
# Out:
#                         Model  Selling_Price  Kilometers_Driven  Year  \
# 0          MarutiWagonR1.0LXI         312165              82238  2014
# 1             ToyotaEtiosLiva         313799              30558  2013
# 2               MarutiAlto800         295999              22164  2018
# 3                 MarutiSwift         435199              30535  2013
# 4             MarutiWagonR1.0         289099              15738  2013
# ...                       ...            ...                ...   ...
# 2232          MarutiWagonR1.0         385999              45263  2015
# 2233              MarutiSwift         324099             100335  2012
# 2234              HyundaiEonD         212299              28016  2011
# 2235  FordEcosport1.5AMBIENTE         378899              87947  2013
# 2236            MarutiAltoK10         304299              33639  2015
#
#              Owner     Fuel_Type Transmission   Insurance  Car_Condition
# ...

# %%
CarData.Transmission.unique()
# Out:
# array(['MANUAL', 'MH12', 'AUTOMATIC', 'UP14', 'UP32', 'KA01', 'HR03',
#        'MH04', 'MH01', 'KA53', 'MH05', 'DL5C', 'TN02', 'GJ27', 'DL2C',
#        'HR26', 'DL12', 'TN06', 'RJ14', 'DL4C', 'TN22', 'KA02', 'KA50',
#        'MH02', 'PB91', 'DL8C', 'KA05', 'GJ18', 'HR51', 'HR29', 'DL10',
#        'MH03', 'KA03', 'KA04', 'GJ05', 'GJ01', 'DL9C', 'MH47', 'TS08',
#        'DL3C', 'MH14', 'MH46', 'UP78', 'GJ06', 'HR05', 'TS09', 'DL11',
#        'MH43', 'PB10', 'KA51', 'DL14', 'HR12', 'DL1C', 'TN12', 'RJ45'],
#       dtype=object)

# %%
CarData.loc[:,'Transmission']
# Out:
# 0       MANUAL
# 1       MANUAL
# 2       MANUAL
# 3       MANUAL
# 4       MANUAL
#          ...
# 2232    MANUAL
# 2233    MANUAL
# 2234    MANUAL
# 2235    MANUAL
# 2236    MANUAL
# Name: Transmission, Length: 2223, dtype: object

# %%
# change data type
CarData.Transmission = CarData.Transmission.astype('category')
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
CarData.loc[:,'Transmission']
# Out:
# 0       MANUAL
# 1       MANUAL
# 2       MANUAL
# 3       MANUAL
# 4       MANUAL
#          ...
# 2232    MANUAL
# 2233    MANUAL
# 2234    MANUAL
# 2235    MANUAL
# 2236    MANUAL
# Name: Transmission, Length: 2223, dtype: category
# Categories (55, object): ['AUTOMATIC', 'DL10', 'DL11', 'DL12', ..., 'TS09', 'UP14', 'UP32', 'UP78']

# %%
CarData.nunique()
# Out:
# Model                 430
# Selling_Price        1917
# Kilometers_Driven    2207
# Year                   15
# Owner                   3
# Fuel_Type               4
# Transmission           55
# Insurance             473
# Car_Condition          19
# dtype: int64

# %%
CarData.Model.unique()
# Out:
# array(['MarutiWagonR1.0LXI', 'ToyotaEtiosLiva', 'MarutiAlto800',
#        'MarutiSwift', 'MarutiWagonR1.0', 'HyundaiElitei20ASTA1.2',
#        'HyundaiGrandi10SPORTZ1.2KAPPA', 'HyundaiElitei20ASTA',
#        'MarutiCelerio', 'MarutiSwiftDzireVXI1.2BS', 'MarutiDzire',
#        'HondaCivic1.8S', 'MarutiAlto800LXI', 'HyundaiVernaFLUIDIC1.6EX',
#        'ToyotaEtiosCROSS1.4', 'HondaCitySVCVT', 'VolkswagenVentoHIGHLINE',
#        'Hyundaii20MAGNAO', 'VolkswagenPoloGT', 'MahindraTUV300',
#        'HondaAmaze1.5VCVT', 'TataNanoXT', 'RenaultKwid', 'MarutiAltoK10',
#        'HyundaiElitei20SPORTZ', 'MarutiZenEstilo', 'MarutiCelerioZXI',
#        'MarutiSwiftDzireVDIBS', 'MarutiBalenoALPHA1.2', 'MarutiSwiftVDI',
#        'TataTiagoXT1.2', 'MahindraBoleroPower+',
#        'HyundaiElitei20MAGNA1.4', 'MarutiSX4', 'MarutiBalenoDELTA1.2K12',
#        'MarutiSwiftVXI', 'HondaCityVMT', 'MahindraXUV500W8',
#        'HyundaiVENUE1.4CRDIMT', 'Hyundaii20MAGNAO1.4', 'MarutiAltoK10VXI',
# ...

# %%
old_text = ['HyundaiGrandi10SPORTZ1.2KAPPA', 'HyundaiElitei20ASTA1.2', 
            'HyundaiElitei20ASTA', 'HyundaiVernaFLUIDIC1.6EX']
new_text = ['Hyundai', 'Hyundai', 'Hyundai', 'Hyundai']

CarData['Model'].replace(to_replace = old_text, value = new_text, inplace = True)
CarData.Model.unique()
# Out:
# array(['MarutiWagonR1.0LXI', 'ToyotaEtiosLiva', 'MarutiAlto800',
#        'MarutiSwift', 'MarutiWagonR1.0', 'Hyundai', 'MarutiCelerio',
#        'MarutiSwiftDzireVXI1.2BS', 'MarutiDzire', 'HondaCivic1.8S',
#        'MarutiAlto800LXI', 'ToyotaEtiosCROSS1.4', 'HondaCitySVCVT',
#        'VolkswagenVentoHIGHLINE', 'Hyundaii20MAGNAO', 'VolkswagenPoloGT',
#        'MahindraTUV300', 'HondaAmaze1.5VCVT', 'TataNanoXT', 'RenaultKwid',
#        'MarutiAltoK10', 'HyundaiElitei20SPORTZ', 'MarutiZenEstilo',
#        'MarutiCelerioZXI', 'MarutiSwiftDzireVDIBS',
#        'MarutiBalenoALPHA1.2', 'MarutiSwiftVDI', 'TataTiagoXT1.2',
#        'MahindraBoleroPower+', 'HyundaiElitei20MAGNA1.4', 'MarutiSX4',
#        'MarutiBalenoDELTA1.2K12', 'MarutiSwiftVXI', 'HondaCityVMT',
#        'MahindraXUV500W8', 'HyundaiVENUE1.4CRDIMT', 'Hyundaii20MAGNAO1.4',
#        'MarutiAltoK10VXI', 'FordEcosport1.5TITANIUMTI',
#        'Hyundaii10SPORTZ1.2', 'HondaBrio1.2VMTI',
# ...

# %%
CarData.nunique()
# Out:
# Model                 427
# Selling_Price        1917
# Kilometers_Driven    2207
# Year                   15
# Owner                   3
# Fuel_Type               4
# Transmission           55
# Insurance             473
# Car_Condition          19
# dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.title("Check Outlier with boxplot for selling price")
CarData.boxplot(column=['Selling_Price']);

# %%
plt.figure(figsize=[22,10])
sns.displot(CarData['Selling_Price'])
plt.title('Selling Price Distribution Plot')
# Out:
# Text(0.5, 1.0, 'Selling Price Distribution Plot')

# %%
plt.figure(figsize=[22,10])
sns.displot(CarData['Kilometers_Driven'])
plt.title('Kilometers Driven Distribution Plot')
# Out:
# Text(0.5, 1.0, 'Kilometers Driven Distribution Plot')

# %%
qMileage = CarData['Kilometers_Driven'].quantile(0.99)
CarData = CarData[CarData['Kilometers_Driven']<qMileage]
sns.displot(CarData['Kilometers_Driven'])
plt.title("Kilometers Driven")
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title("Fuel Type")
order = CarData['Fuel_Type'].value_counts(ascending=False).index
sns.countplot(x='Fuel_Type', data=CarData, order=order)

# %%
CarData['Owner'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.title("Fuel Type pie Chart")
# Out:
# Text(0.5, 1.0, 'Fuel Type pie Chart')

# %%
corrmat = CarData.corr(method='pearson')
top_corr_features = corrmat.index
plt.figure(figsize=(15,15))

g=sns.heatmap(CarData[top_corr_features].corr(method='pearson'),
              annot=True,cmap="RdYlGn")
