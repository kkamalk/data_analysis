# %% [markdown]
# # Mount Drive

# %%
ls
# Out:
# sample_data/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Project Directory path 
project_dir = 'drive/MyDrive/COMPTECH/Data/W1-D1/'

# %%
import glob

# Using '*' pattern 
print('\nNamed with wildcard *:')
for name in glob.glob(project_dir+'*'):
    print(name)
# Out:
# Named with wildcard *:
# drive/MyDrive/COMPTECH/Data/W1-D1/W1-D1.ipynb
# drive/MyDrive/COMPTECH/Data/W1-D1/bak
# drive/MyDrive/COMPTECH/Data/W1-D1/Churn-Modelling.xlsx
# drive/MyDrive/COMPTECH/Data/W1-D1/Churn-Modelling.csv
# drive/MyDrive/COMPTECH/Data/W1-D1/Lecture1_W1_D1.ipynb
# drive/MyDrive/COMPTECH/Data/W1-D1/Churn-Demo-EDA.ipynb
# drive/MyDrive/COMPTECH/Data/W1-D1/boxplot_plot.ipynb

# %%
print(project_dir+'*')
# Out:
# drive/MyDrive/COMPTECH/Data/W1-D1/*

# %%
# Using '*' pattern
print('\nNamed with wildcard *:')
for name in glob.glob(project_dir+'*.csv'):
    print(name)
# Out:
# Named with wildcard *:
# drive/MyDrive/COMPTECH/Data/W1-D1/Churn-Modelling.csv

# %%
import pandas as pd
churn = pd.read_csv(project_dir+ 'Churn-Modelling.csv')

# %%
churn
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2      0K              1          1               1
# 1          1     84K              1          0               1
# 2          8    160K              3          1               0
# 3          1      0K              2          0               0
# 4          2    126K              1          1               1
# ...      ...     ...            ...        ...             ...
# 9995       5      0K              2          1               0
# 9996      10     57K              1          1               1
# 9997       7      0K              1          0               1
# 9998       3     75K              2          1               0
# 9999       4    130K              1          1               0
#
#       EstimatedSalary  Exited  Unnamed: 14
# 0           101348.88       1          NaN
# 1           112542.58       0          NaN
# 2           113931.57       1          NaN
# 3            93826.63       0          NaN
# 4            79084.10       0          NaN
# ...               ...     ...          ...
# 9995         96270.64       0          NaN
# 9996        101699.77       0          NaN
# 9997         42085.58       1          NaN
# 9998         92888.52       1          NaN
# 9999         38190.78       0          NaN
#
# [10000 rows x 15 columns]

# %%
type(churn)
# Out:
# pandas.core.frame.DataFrame

# %%
#set the RowNumber (Column zero) as the DataFrame Index
#this replaces the default index created by pandas
#notice we have one less column (14 instead of 15)
churn = pd.read_csv(project_dir+ 'Churn-Modelling.csv', index_col=0)
churn
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 1              0K              1          1               1        101348.88
# 2             84K              1          0               1        112542.58
# 3            160K              3          1               0        113931.57
# 4              0K              2          0               0         93826.63
# 5            126K              1          1               1         79084.10
# ...           ...            ...        ...             ...              ...
# 9996           0K              2          1               0         96270.64
# 9997          57K              1          1               1        101699.77
# 9998           0K              1          0               1         42085.58
# 9999          75K              2          1               0         92888.52
# 10000        130K              1          1               0         38190.78
#
#            Exited  Unnamed: 14
# RowNumber
# 1               1          NaN
# 2               0          NaN
# 3               1          NaN
# 4               0          NaN
# 5               0          NaN
# ...           ...          ...
# 9996            0          NaN
# 9997            0          NaN
# 9998            1          NaN
# 9999            1          NaN
# 10000           0          NaN
#
# [10000 rows x 14 columns]

# %% [markdown]
# # Simple Exporatory Data Analysis (EDA)

# %%
churn.head(7)
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
# 6            15574012       Chu          645     Spain    Male   44       8
# 7            15592531  Bartlett          822    France    Male   50       7
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 1              0K              1          1               1        101348.88
# 2             84K              1          0               1        112542.58
# 3            160K              3          1               0        113931.57
# 4              0K              2          0               0         93826.63
# 5            126K              1          1               1         79084.10
# 6            114K              2          1               0        149756.71
# 7              0K              2          1               1         10062.80
#
#            Exited  Unnamed: 14
# RowNumber
# 1               1          NaN
# 2               0          NaN
# 3               1          NaN
# 4               0          NaN
# 5               0          NaN
# 6               1          NaN
# 7               0          NaN

# %%
churn.tail(10)
# Out:
#            CustomerId      Surname  CreditScore Geography  Gender  Age  \
# RowNumber
# 9991         15798964   Nkemakonam          714   Germany    Male   33
# 9992         15769959  Ajuluchukwu          597    France  Female   53
# 9993         15657105  Chukwualuka          726     Spain    Male   36
# 9994         15569266       Rahman          644    France    Male   28
# 9995         15719294         Wood          800    France  Female   29
# 9996         15606229     Obijiaku          771    France    Male   39
# 9997         15569892    Johnstone          516    France    Male   35
# 9998         15584532          Liu          709    France  Female   36
# 9999         15682355    Sabbatini          772   Germany    Male   42
# 10000        15628319       Walker          792    France  Female   28
#
#            Tenure Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 9991            3     35K              1          1               0
# 9992            4     88K              1          1               0
# 9993            2      0K              1          1               0
# 9994            7    155K              1          1               0
# 9995            2      0K              2          0               0
# 9996            5      0K              2          1               0
# 9997           10     57K              1          1               1
# 9998            7      0K              1          0               1
# 9999            3     75K              2          1               0
# 10000           4    130K              1          1               0
#
#            EstimatedSalary  Exited  Unnamed: 14
# RowNumber
# 9991              53667.08       0          NaN
# 9992              69384.71       1          NaN
# 9993             195192.40       0          NaN
# 9994              29179.52       0          NaN
# 9995             167773.55       0          NaN
# 9996              96270.64       0          NaN
# 9997             101699.77       0          NaN
# 9998              42085.58       1          NaN
# 9999              92888.52       1          NaN
# 10000             38190.78       0          NaN

# %%
churn.sample(5)
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 7555         15569917  Obijiaku          706     Spain    Male   30       6
# 89           15622897    Sharpe          646    France  Female   46       4
# 3629         15573319  Azubuike          493   Germany  Female   35       8
# 4177         15579808    Kramer          754   Germany  Female   39       8
# 8662         15604020    Otoole          773   Germany  Female   36       4
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 7555          88K              2          0               0        137674.55
# 89             0K              3          1               0         93251.42
# 3629         178K              1          0               0        197428.64
# 4177         129K              1          1               1         87684.93
# 8662         106K              1          0               1          4395.45
#
#            Exited  Unnamed: 14
# RowNumber
# 7555            1          NaN
# 89              1          NaN
# 3629            0          NaN
# 4177            0          NaN
# 8662            0          NaN

# %%
type(churn)
# Out:
# pandas.core.frame.DataFrame

# %%
churn.shape
# Out:
# (10000, 14)

# %%
churn.shape[1]
# Out:
# 14

# %%
churn.shape[0]
# Out:
# 10000

# %%
type(churn.shape)
# Out:
# tuple

# %%
# Try this
# churn.shape[2]

# %%
type (churn.shape[1])
# Out:
# int

# %%
churn.Gender == 'Male'
# Out:
# RowNumber
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 9996      True
# 9997      True
# 9998     False
# 9999      True
# 10000    False
# Name: Gender, Length: 10000, dtype: bool

# %%
type(churn.Gender == 'Male')
# Out:
# pandas.core.series.Series

# %%
males =  churn[churn.Gender == 'Male']
males
# Out:
#            CustomerId      Surname  CreditScore Geography Gender  Age  Tenure  \
# RowNumber
# 6            15574012          Chu          645     Spain   Male   44       8
# 7            15592531     Bartlett          822    France   Male   50       7
# 9            15792365           He          501    France   Male   44       4
# 10           15592389           H?          684    France   Male   27       2
# 11           15767821       Bearce          528    France   Male   31       6
# ...               ...          ...          ...       ...    ...  ...     ...
# 9993         15657105  Chukwualuka          726     Spain   Male   36       2
# 9994         15569266       Rahman          644    France   Male   28       7
# 9996         15606229     Obijiaku          771    France   Male   39       5
# 9997         15569892    Johnstone          516    France   Male   35      10
# 9999         15682355    Sabbatini          772   Germany   Male   42       3
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 6            114K              2          1               0        149756.71
# 7              0K              2          1               1         10062.80
# 9            142K              2          0               1         74940.50
# 10           135K              1          1               1         71725.73
# 11           102K              2          0               0         80181.12
# ...           ...            ...        ...             ...              ...
# 9993           0K              1          1               0        195192.40
# 9994         155K              1          1               0         29179.52
# 9996           0K              2          1               0         96270.64
# 9997          57K              1          1               1        101699.77
# 9999          75K              2          1               0         92888.52
#
#            Exited  Unnamed: 14
# RowNumber
# 6               1          NaN
# 7               0          NaN
# 9               0          NaN
# 10              0          NaN
# 11              0          NaN
# ...           ...          ...
# 9993            0          NaN
# 9994            0          NaN
# 9996            0          NaN
# 9997            0          NaN
# 9999            1          NaN
#
# [5457 rows x 14 columns]

# %%
type(males)
# Out:
# pandas.core.frame.DataFrame

# %%
males.shape
# Out:
# (5457, 14)

# %%
males.shape[0]
# Out:
# 5457

# %%
males.shape[0]/churn.shape[0]
# Out:
# 0.5457

# %%
churn[churn.Gender== 'Male']
# Out:
#            CustomerId      Surname  CreditScore Geography Gender  Age  Tenure  \
# RowNumber
# 6            15574012          Chu          645     Spain   Male   44       8
# 7            15592531     Bartlett          822    France   Male   50       7
# 9            15792365           He          501    France   Male   44       4
# 10           15592389           H?          684    France   Male   27       2
# 11           15767821       Bearce          528    France   Male   31       6
# ...               ...          ...          ...       ...    ...  ...     ...
# 9993         15657105  Chukwualuka          726     Spain   Male   36       2
# 9994         15569266       Rahman          644    France   Male   28       7
# 9996         15606229     Obijiaku          771    France   Male   39       5
# 9997         15569892    Johnstone          516    France   Male   35      10
# 9999         15682355    Sabbatini          772   Germany   Male   42       3
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 6            114K              2          1               0        149756.71
# 7              0K              2          1               1         10062.80
# 9            142K              2          0               1         74940.50
# 10           135K              1          1               1         71725.73
# 11           102K              2          0               0         80181.12
# ...           ...            ...        ...             ...              ...
# 9993           0K              1          1               0        195192.40
# 9994         155K              1          1               0         29179.52
# 9996           0K              2          1               0         96270.64
# 9997          57K              1          1               1        101699.77
# 9999          75K              2          1               0         92888.52
#
#            Exited  Unnamed: 14
# RowNumber
# 6               1          NaN
# 7               0          NaN
# 9               0          NaN
# 10              0          NaN
# 11              0          NaN
# ...           ...          ...
# 9993            0          NaN
# 9994            0          NaN
# 9996            0          NaN
# 9997            0          NaN
# 9999            1          NaN
#
# [5457 rows x 14 columns]

# %%
churn.groupby(["Geography", "Gender"])["Exited"].count()
# Out:
# Geography  Gender
# France     Female    2261
#            Male      2753
# Germany    Female    1193
#            Male      1316
# Spain      Female    1089
#            Male      1388
# Name: Exited, dtype: int64

# %%
# data_groupby_sex_describe=data.groupby('SEX').describe()

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  object
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
#  13  Unnamed: 14      0 non-null      float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 1.1+ MB

# %%
# churn.count().isnull()
churn['Age'].isna().sum()
# Out:
# 0

# %%
churn['Unnamed: 14'].isna().sum()
# Out:
# 10000

# %%
# all the content of column 13 is NaN (NaN), we can safely delete this column
churn['Unnamed: 14']
# Out:
# RowNumber
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 9996    NaN
# 9997    NaN
# 9998    NaN
# 9999    NaN
# 10000   NaN
# Name: Unnamed: 14, Length: 10000, dtype: float64

# %%
churn[:5].isna().sum()

# %%
del churn['Unnamed: 14']

# %%
# we now have 13 columns
churn
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 1              0K              1          1               1        101348.88
# 2             84K              1          0               1        112542.58
# 3            160K              3          1               0        113931.57
# 4              0K              2          0               0         93826.63
# 5            126K              1          1               1         79084.10
# ...           ...            ...        ...             ...              ...
# 9996           0K              2          1               0         96270.64
# 9997          57K              1          1               1        101699.77
# 9998           0K              1          0               1         42085.58
# 9999          75K              2          1               0         92888.52
# 10000        130K              1          1               0         38190.78
#
#            Exited
# RowNumber
# 1               1
# 2               0
# 3               1
# 4               0
# 5               0
# ...           ...
# 9996            0
# 9997            0
# 9998            1
# 9999            1
# 10000           0
#
# [10000 rows x 13 columns]

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  object
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 1.1+ MB

# %% [markdown]
# # selcting rows

# %%
# selecting by rows
churn[1:5]
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 2             84K              1          0               1        112542.58
# 3            160K              3          1               0        113931.57
# 4              0K              2          0               0         93826.63
# 5            126K              1          1               1         79084.10
#
#            Exited
# RowNumber
# 2               0
# 3               1
# 4               0
# 5               0

# %%
churn[0:5]
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 1              0K              1          1               1        101348.88
# 2             84K              1          0               1        112542.58
# 3            160K              3          1               0        113931.57
# 4              0K              2          0               0         93826.63
# 5            126K              1          1               1         79084.10
#
#            Exited
# RowNumber
# 1               1
# 2               0
# 3               1
# 4               0
# 5               0

# %%
churn[-2:-1]
# Out:
#            CustomerId    Surname  CreditScore Geography Gender  Age  Tenure  \
# RowNumber
# 9999         15682355  Sabbatini          772   Germany   Male   42       3
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 9999          75K              2          1               0         92888.52
#
#            Exited
# RowNumber
# 9999            1

# %%
churn.loc[5,'CustomerId']
# Out:
# 15737888

# %%
# churn.loc[0,'CustomerId']

# %%
churn.iloc[4,0]
# Out:
# 15737888

# %%
churn.loc[:,'CustomerId']
# Out:
# RowNumber
# 1        15634602
# 2        15647311
# 3        15619304
# 4        15701354
# 5        15737888
#            ...
# 9996     15606229
# 9997     15569892
# 9998     15584532
# 9999     15682355
# 10000    15628319
# Name: CustomerId, Length: 10000, dtype: int64

# %%
churn.iloc[:,5]
# Out:
# RowNumber
# 1        42
# 2        41
# 3        42
# 4        39
# 5        43
#          ..
# 9996     39
# 9997     35
# 9998     36
# 9999     42
# 10000    28
# Name: Age, Length: 10000, dtype: int64

# %%
churn[:5].isna().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
churn.describe()
# Out:
#          CustomerId   CreditScore           Age        Tenure  NumOfProducts  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800       1.530200
# std    7.193619e+04     96.653299     10.487806      2.892174       0.581654
# min    1.556570e+07    350.000000     18.000000      0.000000       1.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       1.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000       1.000000
# 75%    1.575323e+07    718.000000     44.000000      7.000000       2.000000
# max    1.581569e+07    850.000000     92.000000     10.000000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000    10000.000000     10000.000000  10000.000000
# mean       0.70550        0.515100    100090.239881      0.203700
# std        0.45584        0.499797     57510.492818      0.402769
# min        0.00000        0.000000        11.580000      0.000000
# 25%        0.00000        0.000000     51002.110000      0.000000
# 50%        1.00000        1.000000    100193.915000      0.000000
# 75%        1.00000        1.000000    149388.247500      0.000000
# max        1.00000        1.000000    199992.480000      1.000000

# %%
# overall correlations
churn.corr()
# Out:
#                  CustomerId  CreditScore       Age    Tenure  NumOfProducts  \
# CustomerId         1.000000     0.005308  0.009497 -0.014883       0.016972
# CreditScore        0.005308     1.000000 -0.003965  0.000842       0.012238
# Age                0.009497    -0.003965  1.000000 -0.009997      -0.030680
# Tenure            -0.014883     0.000842 -0.009997  1.000000       0.013444
# NumOfProducts      0.016972     0.012238 -0.030680  0.013444       1.000000
# HasCrCard         -0.014025    -0.005458 -0.011721  0.022583       0.003183
# IsActiveMember     0.001665     0.025651  0.085472 -0.028362       0.009612
# EstimatedSalary    0.015271    -0.001384 -0.007201  0.007784       0.014204
# Exited            -0.006248    -0.027094  0.285323 -0.014001      -0.047820
#
#                  HasCrCard  IsActiveMember  EstimatedSalary    Exited
# CustomerId       -0.014025        0.001665         0.015271 -0.006248
# CreditScore      -0.005458        0.025651        -0.001384 -0.027094
# Age              -0.011721        0.085472        -0.007201  0.285323
# Tenure            0.022583       -0.028362         0.007784 -0.014001
# NumOfProducts     0.003183        0.009612         0.014204 -0.047820
# HasCrCard         1.000000       -0.011866        -0.009933 -0.007138
# IsActiveMember   -0.011866        1.000000        -0.011421 -0.156128
# EstimatedSalary  -0.009933       -0.011421         1.000000  0.012097
# Exited           -0.007138       -0.156128         0.012097  1.000000

# %%
churn.describe(include=['O'])
# Out:
#        Surname Geography Gender Balance
# count    10000     10000  10000   10000
# unique    2932         3      2     195
# top      Smith    France   Male      0K
# freq        32      5014   5457    3617

# %%
churn.describe(include='all')
# Out:
#           CustomerId Surname   CreditScore Geography Gender           Age  \
# count   1.000000e+04   10000  10000.000000     10000  10000  10000.000000
# unique           NaN    2932           NaN         3      2           NaN
# top              NaN   Smith           NaN    France   Male           NaN
# freq             NaN      32           NaN      5014   5457           NaN
# mean    1.569094e+07     NaN    650.528800       NaN    NaN     38.921800
# std     7.193619e+04     NaN     96.653299       NaN    NaN     10.487806
# min     1.556570e+07     NaN    350.000000       NaN    NaN     18.000000
# 25%     1.562853e+07     NaN    584.000000       NaN    NaN     32.000000
# 50%     1.569074e+07     NaN    652.000000       NaN    NaN     37.000000
# 75%     1.575323e+07     NaN    718.000000       NaN    NaN     44.000000
# max     1.581569e+07     NaN    850.000000       NaN    NaN     92.000000
#
#               Tenure Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000   10000.000000  10000.00000    10000.000000
# unique           NaN     195            NaN          NaN             NaN
# top              NaN      0K            NaN          NaN             NaN
# freq             NaN    3617            NaN          NaN             NaN
# mean        5.012800     NaN       1.530200      0.70550        0.515100
# std         2.892174     NaN       0.581654      0.45584        0.499797
# min         0.000000     NaN       1.000000      0.00000        0.000000
# 25%         3.000000     NaN       1.000000      0.00000        0.000000
# 50%         5.000000     NaN       1.000000      1.00000        1.000000
# 75%         7.000000     NaN       2.000000      1.00000        1.000000
# max        10.000000     NaN       4.000000      1.00000        1.000000
#
#         EstimatedSalary        Exited
# count      10000.000000  10000.000000
# unique              NaN           NaN
# top                 NaN           NaN
# freq                NaN           NaN
# mean      100090.239881      0.203700
# std        57510.492818      0.402769
# min           11.580000      0.000000
# 25%        51002.110000      0.000000
# 50%       100193.915000      0.000000
# 75%       149388.247500      0.000000
# max       199992.480000      1.000000

# %%
g1 = churn.groupby(['Gender']).size(); g1
# Out:
# Gender
# Female    4543
# Male      5457
# dtype: int64

# %%
g1 = churn.groupby(['Geography']).size(); g1
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# dtype: int64

# %% [markdown]
# # Additional EDA

# %%
churn['Age']
# Out:
# RowNumber
# 1        42
# 2        41
# 3        42
# 4        39
# 5        43
#          ..
# 9996     39
# 9997     35
# 9998     36
# 9999     42
# 10000    28
# Name: Age, Length: 10000, dtype: int64

# %%
churn.Age
# Out:
# RowNumber
# 1        42
# 2        41
# 3        42
# 4        39
# 5        43
#          ..
# 9996     39
# 9997     35
# 9998     36
# 9999     42
# 10000    28
# Name: Age, Length: 10000, dtype: int64

# %%
type(churn.Age)
# Out:
# pandas.core.series.Series

# %%
churn[['Age']]
# Out:
#            Age
# RowNumber
# 1           42
# 2           41
# 3           42
# 4           39
# 5           43
# ...        ...
# 9996        39
# 9997        35
# 9998        36
# 9999        42
# 10000       28
#
# [10000 rows x 1 columns]

# %%
type(churn['Age'])
# Out:
# pandas.core.series.Series

# %%
type(churn[['Age']])
# Out:
# pandas.core.frame.DataFrame

# %%
Age = churn['Age']
Age
# Out:
# RowNumber
# 1        42
# 2        41
# 3        42
# 4        39
# 5        43
#          ..
# 9996     39
# 9997     35
# 9998     36
# 9999     42
# 10000    28
# Name: Age, Length: 10000, dtype: int64

# %%
Age = churn.Age 
Age
# Out:
# RowNumber
# 1        42
# 2        41
# 3        42
# 4        39
# 5        43
#          ..
# 9996     39
# 9997     35
# 9998     36
# 9999     42
# 10000    28
# Name: Age, Length: 10000, dtype: int64

# %%
type(Age)
# Out:
# pandas.core.series.Series

# %%
Age.value_counts()
# Out:
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
#      ...
# 92      2
# 82      1
# 88      1
# 85      1
# 83      1
# Name: Age, Length: 70, dtype: int64

# %%
Age.describe()
# Out:
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: Age, dtype: float64

# %%
Age.describe()[1]
# Out:
# 38.9218

# %%
Age.describe()[-1]
# Out:
# 92.0

# %%
Age.mean()
# Out:
# 38.9218

# %% [markdown]
# # Change column order

# %%
churn.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
newColOrder = ['CustomerId', 'Geography','Surname', 'CreditScore', 'Gender', 'Age',
       'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
       'EstimatedSalary', 'Exited']

# %%
churn = churn[newColOrder]
churn
# Out:
#            CustomerId Geography    Surname  CreditScore  Gender  Age  Tenure  \
# RowNumber
# 1            15634602    France   Hargrave          619  Female   42       2
# 2            15647311     Spain       Hill          608  Female   41       1
# 3            15619304    France       Onio          502  Female   42       8
# 4            15701354    France       Boni          699  Female   39       1
# 5            15737888     Spain   Mitchell          850  Female   43       2
# ...               ...       ...        ...          ...     ...  ...     ...
# 9996         15606229    France   Obijiaku          771    Male   39       5
# 9997         15569892    France  Johnstone          516    Male   35      10
# 9998         15584532    France        Liu          709  Female   36       7
# 9999         15682355   Germany  Sabbatini          772    Male   42       3
# 10000        15628319    France     Walker          792  Female   28       4
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 1              0K              1          1               1        101348.88
# 2             84K              1          0               1        112542.58
# 3            160K              3          1               0        113931.57
# 4              0K              2          0               0         93826.63
# 5            126K              1          1               1         79084.10
# ...           ...            ...        ...             ...              ...
# 9996           0K              2          1               0         96270.64
# 9997          57K              1          1               1        101699.77
# 9998           0K              1          0               1         42085.58
# 9999          75K              2          1               0         92888.52
# 10000        130K              1          1               0         38190.78
#
#            Exited
# RowNumber
# 1               1
# 2               0
# 3               1
# 4               0
# 5               0
# ...           ...
# 9996            0
# 9997            0
# 9998            1
# 9999            1
# 10000           0
#
# [10000 rows x 13 columns]

# %% [markdown]
# # change the index

# %%
print (churn.CustomerId.count())
print (churn.CustomerId.nunique())
# Out:
# 10000
# 10000

# %%
# churn = churn.set_index('CustomerId')
# churn

# %%
churn.set_index('CustomerId', inplace=True)
churn
# Out:
#            Geography    Surname  CreditScore  Gender  Age  Tenure Balance  \
# CustomerId
# 15634602      France   Hargrave          619  Female   42       2      0K
# 15647311       Spain       Hill          608  Female   41       1     84K
# 15619304      France       Onio          502  Female   42       8    160K
# 15701354      France       Boni          699  Female   39       1      0K
# 15737888       Spain   Mitchell          850  Female   43       2    126K
# ...              ...        ...          ...     ...  ...     ...     ...
# 15606229      France   Obijiaku          771    Male   39       5      0K
# 15569892      France  Johnstone          516    Male   35      10     57K
# 15584532      France        Liu          709  Female   36       7      0K
# 15682355     Germany  Sabbatini          772    Male   42       3     75K
# 15628319      France     Walker          792  Female   28       4    130K
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15634602                1          1               1        101348.88       1
# 15647311                1          0               1        112542.58       0
# 15619304                3          1               0        113931.57       1
# 15701354                2          0               0         93826.63       0
# 15737888                1          1               1         79084.10       0
# ...                   ...        ...             ...              ...     ...
# 15606229                2          1               0         96270.64       0
# 15569892                1          1               1        101699.77       0
# 15584532                1          0               1         42085.58       1
# 15682355                2          1               0         92888.52       1
# 15628319                1          1               0         38190.78       0
#
# [10000 rows x 12 columns]

# %%
churn.shape
# Out:
# (10000, 12)
