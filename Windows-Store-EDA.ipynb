# %% [markdown]
# ## Read about the data source and understand the context

# %% [markdown]
# Data Source:
#
# https://www.kaggle.com/quadeer15sh/windows-store-top-apps-games

# %%
#import the useful libraries.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load the data

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('drive/MyDrive/COMPTECH/Data/W1-D3/WindowsStore/windows_store.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Display a sample of the dataset

# %%
df
# Out:
#                                 Name     Price  \
# 0                   WhatsApp Desktop      Free
# 1                   Telegram Desktop      Free
# 2     Amazon Prime Video for Windows      Free
# 3                          Instagram      Free
# 4                      Spotify Music      Free
# ...                              ...       ...
# 3955           Vegas Slots Machine *  ₹ 109.00
# 3956              Crossword Puzzle +  ₹ 109.00
# 3957                     Rescue Team  ₹ 219.00
# 3958                  Doodle Kingdom   ₹ 29.00
# 3959                    Doodle Devil   ₹ 29.00
#
#                                             Description  \
# 0     With WhatsApp on the desktop, you can seamless...
# 1     Pure instant messaging — simple, fast, secure,...
# 2     Watch movies and TV shows recommended for you,...
# 3     Bringing you closer to the people and things y...
# 4     Love music? Play your favorite songs and album...
# ...

# %% [markdown]
# ## Extract single row from dataframe

# %%
df.values[0]
# Out:
# array(['WhatsApp Desktop', 'Free',
#        'With WhatsApp on the desktop, you can seamlessly sync all of your chats to your computer so that you can chat on whatever device is most convenient to you.',
#        'WhatsApp Inc.', '01-02-2017', 'Social', '379.39 MB',
#        'For ages 3 and up', 'English(UnitedStates)'], dtype=object)

# %%
df.values[4]
# Out:
# array(['Spotify Music', 'Free',
# ...

# %%
df.values[100]
# Out:
# array(['Cinebench', 'Free',
# ...

# %% [markdown]
# ## Extract specific cell

# %%
df.values[100,1]
# Out:
# 'Free'

# %%
df.values[100,0]
# Out:
# 'Cinebench'

# %% [markdown]
# ## Display number of rows/columns

# %%
df.shape
# Out:
# (3960, 9)

# %% [markdown]
# ## check for nulls and default data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3960 entries, 0 to 3959
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             3960 non-null   object
#  1   Price            3960 non-null   object
#  2   Description      3960 non-null   object
#  3   Publisher        3960 non-null   object
#  4   Date of Release  3954 non-null   object
#  5   Category         3960 non-null   object
#  6   Size             3642 non-null   object
#  7   Age Rating       3960 non-null   object
#  8   Languages        3908 non-null   object
# dtypes: object(9)
# memory usage: 278.6+ KB

# %% [markdown]
# ## Check the number of nulls

# %%
df.isnull().sum()
# Out:
# Name                 0
# Price                0
# Description          0
# Publisher            0
# Date of Release      6
# Category             0
# Size               318
# Age Rating           0
# Languages           52
# dtype: int64

# %% [markdown]
# ## Does the number of nulls agree with the number of nulls you observed by running the df.info command?

# %%
# Extract column names
df.columns
# Out:
# Index(['Name', 'Price', 'Description', 'Publisher', 'Date of Release',
#        'Category', 'Size', 'Age Rating', 'Languages'],
#       dtype='object')

# %% [markdown]
# ## For numeric values, describe would provide values such as mean, min, max, std. deviation. Observe how price data was not considered numeric due to the presence of (Free) values

# %%
df.describe()
# Out:
#                     Name Price  \
# count               3960  3960
# unique              3960   254
# top     WhatsApp Desktop  Free
# freq                   1  1974
#
#                                               Description  \
# count                                                3960
# unique                                               3889
# top     World No.1 Typing tutor, Easy Typing Practice ...
# freq                                                    8
#
#                     Publisher Date of Release            Category      Size  \
# count                    3960            3954                3960      3642
# unique                   1663            1724                  87      3113
# top     Microsoft Corporation      09-06-2019  Action & adventure  10.12 MB
# freq                      256              21                 864        12
#
#                Age Rating              Languages
# count                3960                   3908
# ...

# %% [markdown]
# ## Note the insight you gain when describing categorical features

# %%
df.describe(include=['O'])
# Out:
#                     Name Price  \
# count               3960  3960
# unique              3960   254
# top     WhatsApp Desktop  Free
# freq                   1  1974
#
#                                               Description  \
# count                                                3960
# unique                                               3889
# top     World No.1 Typing tutor, Easy Typing Practice ...
# freq                                                    8
#
#                     Publisher Date of Release            Category      Size  \
# count                    3960            3954                3960      3642
# unique                   1663            1724                  87      3113
# top     Microsoft Corporation      09-06-2019  Action & adventure  10.12 MB
# freq                      256              21                 864        12
#
#                Age Rating              Languages
# count                3960                   3908
# ...

# %% [markdown]
# ## Identify unique publishers in the dataset

# %%
df.Publisher.unique()
# Out:
# array(['WhatsApp Inc.', 'Telegram Messenger LLP',
#        'Amazon Development Centre (London) Ltd', ..., 'Cool Inc.',
#        'App Best', 'JoyBits Ltd'], dtype=object)

# %%
df.Publisher.unique().size
# Out:
# 1663

# %% [markdown]
# ## Notice that the array was not displayed in full

# %%
np.set_printoptions(threshold=np.inf)

# %%
df.Publisher.unique()
# Out:
# array(['WhatsApp Inc.', 'Telegram Messenger LLP',
#        'Amazon Development Centre (London) Ltd', 'Instagram',
#        'Spotify AB', 'Netflix, Inc.', 'VideoLAN', 'Microsoft Corporation',
#        'Apple Inc.', 'Python Software Foundation', 'rocksdanister',
#        'Adobe Inc.', 'Facebook Inc', 'Dolby Laboratories',
#        'AMZN Mobile LLC.', 'AMZN Mobile LLC',
#        'Kingsoft Office Software Corporation Limited',
#        'SHAREit Technologies Co.Ltd',
#        'Wuhan Net Power Technology Co., Ltd', 'FLIPKART', 'PicsArt Inc.',
#        'Pinterest Inc.', 'Pango Inc.', 'Screenovate Technologies',
#        'Charles Milette', 'Zoom Video Communications, Inc.', 'DTS, Inc.',
#        'Times Internet, Limited', 'Drawboard', 'Canonical Group Limited',
#        'Zero Byte', 'Lion Group', 'V3TApps', 'Free Software Apps',
#        'Skylum Software USA, Inc.', 'Ookla', 'winuwp', 'IOForth',
#        'NVIDIA Corp.', 'Arduino LLC', 'PDF reader apps', 'Saavn',
# ...

# %%
df.Publisher.value_counts()
# Out:
# Microsoft Corporation                          256
# Big Fish Games                                  73
# Xbox Game Studios                               61
# Artifex Mundi                                   55
# Bethesda Softworks                              36
#                                               ...
# Global Delight Technologies Pvt. Ltd.            1
# HUNGAMA DIGITAL MEDIA ENTERTAINMENT Pvt Ltd      1
# DigiDNA                                          1
# Claudia Wey                                      1
# WhatsApp Inc.                                    1
# Name: Publisher, Length: 1663, dtype: int64

# %% [markdown]
# ## Show top 10

# %%
df.Publisher.value_counts().head(10)
# Out:
# Microsoft Corporation          256
# Big Fish Games                  73
# Xbox Game Studios               61
# Artifex Mundi                   55
# Bethesda Softworks              36
# Yellow Elephant Productions     36
# Microsoft Studios               31
# G5 Entertainment AB             27
# AppStream Studios               26
# RV AppStudios                   25
# Name: Publisher, dtype: int64

# %%
df.Publisher.value_counts(ascending = True)
# Out:
# WhatsApp Inc.                 1
# Knowledge Adventure Inc.      1
# METRO TRAINS MELBOURNE        1
# mifi.no                       1
# goatgame                      1
#                            ...
# Bethesda Softworks           36
# Artifex Mundi                55
# Xbox Game Studios            61
# Big Fish Games               73
# Microsoft Corporation       256
# Name: Publisher, Length: 1663, dtype: int64

# %%
df.Publisher.value_counts(ascending = False).head(20)
# Out:
# Microsoft Corporation                  256
# Big Fish Games                          73
# Xbox Game Studios                       61
# Artifex Mundi                           55
# Bethesda Softworks                      36
# Yellow Elephant Productions             36
# Microsoft Studios                       31
# G5 Entertainment AB                     27
# AppStream Studios                       26
# RV AppStudios                           25
# HAMSTER Corporation                     25
# NovaSoftwares                           22
# Wuhan Net Power Technology Co., Ltd     22
# FIVE-BN STUDIO                          21
# Gameloft SE                             19
# Extreme Developers                      18
# Paradox Interactive                     18
# Devolver Digital                        16
# NCH Software                            16
# Focus Home Interactive                  15
# Name: Publisher, dtype: int64

# %%
list(df.columns)
# Out:
# ['Name',
#  'Price',
#  'Description',
#  'Publisher',
#  'Date of Release',
#  'Category',
#  'Size',
#  'Age Rating',
#  'Languages']

# %%
feature_names=list(df.columns)
sampledf = pd.DataFrame([[f, df[f].dtype, df[f].nunique()] for f in feature_names], 
              columns=['feature', 'type', 'distinct values'])
sampledf
# Out:
#            feature    type  distinct values
# 0             Name  object             3960
# 1            Price  object              254
# 2      Description  object             3889
# 3        Publisher  object             1663
# 4  Date of Release  object             1724
# 5         Category  object               87
# 6             Size  object             3113
# 7       Age Rating  object                6
# 8        Languages  object              798

# %%
sampledf.T
# Out:
#                       0       1            2          3                4  \
# feature            Name   Price  Description  Publisher  Date of Release
# type             object  object       object     object           object
# distinct values    3960     254         3889       1663             1724
#
#                         5       6           7          8
# feature          Category    Size  Age Rating  Languages
# type               object  object      object     object
# distinct values        87    3113           6        798

# %% [markdown]
# - Explore the Price column.  Note that you will have do to extract the numeric values from the text

# %%
df.Price.value_counts()
# Out:
# Free                                                                                           1974
# ₹ 269.00                                                                                        240
# Included\r\n            \n\n\n with  Game Pass                                                  137
# ₹ 549.00                                                                                        132
# Included\r\n            \n\n\n+\n with  Game Pass                                               109
#                                                                                                ...
# Full price was ₹ 1,099.00\n₹ 1,099.00\n \nNow ₹ 989.10\n₹ 989.10\n\n with  Game Pass              1
# ₹ 1,999.00                                                                                        1
# Full price was ₹ 5,999.00\n₹ 5,999.00\n \nNow ₹ 4,799.20\n₹ 4,799.20\n\n+\n with  Game Pass       1
# ...

# %% [markdown]
# # DISCLAIMER: FOR CODE DEMO PURPOSES ONLY, MAKE SURE TO PROPERLY LABEL YOUR CHARTS

# %%
#plot the bar graph of percentage Age Rating categories
df['Age Rating'].value_counts(normalize=True).plot.barh()
plt.show()

# %%
# Replace the horizontal bar plot with a pie chart
df['Age Rating'].value_counts(normalize=True).plot.pie()
plt.show()
